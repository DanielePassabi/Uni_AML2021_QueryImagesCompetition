# %% [markdown]
# # Explore features

# %%
import pandas as pd

print("Libraries imported")
# Out:
# Libraries imported

# %%
gallery_features = pd.read_pickle("gallery_features.pkl")
query_features = pd.read_pickle("query_features.pkl")

# %%
idx = 0
tot = 20
for key, value in features.items():
    if idx < tot:
        print("Key:", key)
        print("Value:", value[0:5])
        print("="*100)
        idx += 1
# Out:
# Key: british_museum0
# Value: [0.5156588  0.00852909 0.         0.         0.        ]
# ...
# Key: british_museum1
# Value: [0.26807007 0.00879139 0.         0.         0.        ]
# ...
# Key: british_museum2
# Value: [5.7882589e-01 2.1657786e-01 4.0576648e-05 0.0000000e+00 0.0000000e+00]
# ...
# Key: british_museum3
# Value: [0.48854664 0.03359816 0.         0.         0.        ]
# ...
# Key: british_museum4
# Value: [0.16236477 0.         0.         0.         0.        ]
# ...
# Key: brtish_museum1
# Value: [0.32288677 0.00718955 0.         0.         0.        ]
# ...
# Key: brtish_museum2
# Value: [0.03844818 0.01583001 0.         0.         0.        ]
# ...
# Key: brtish_museum3
# Value: [0.08034071 0.00601784 0.         0.         0.        ]
# ...
# Key: brtish_museum4
# Value: [1.1452577e-01 9.8419301e-03 5.7370043e-03 9.8913864e-05 0.0000000e+00]
# ...
# Key: brtish_museum5
# Value: [6.9694078e-01 1.4134723e-05 0.0000000e+00 0.0000000e+00 0.0000000e+00]
# ...
# Key: brtish_museum6
# ...
